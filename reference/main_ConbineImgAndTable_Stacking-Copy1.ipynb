# %%
from kaggle.api.kaggle_api_extended import KaggleApi
import torch
import torchvision
import torch.nn.functional as F
import torch.nn as nn
import torchtoolbox.transform as transforms
from torch.utils.data import Dataset, DataLoader, Subset
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import StratifiedKFold, GroupKFold
import pandas as pd
import numpy as np
import gc
import os
import cv2
import time
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from efficientnet_pytorch import EfficientNet
# %matplotlib inline

# %% [markdown]
# ## config(kernel使うときに変更すべき変数)

# %%
# config
melanoma_external_malignant_256 = "/home/tidal/ML_Data/SIIM-ISIC_Melanoma_Classification/melanoma_external_malignant_256/"
SIIM_ISIC_Melanoma_Classification = "/home/tidal/ML_Data/SIIM-ISIC_Melanoma_Classification/SIIM-ISIC-Melanoma-Classification/"
Output = "/home/tidal/ML_Data/SIIM-ISIC_Melanoma_Classification/Output/"

# %% [markdown]
# ## データ加工部

# %% [markdown]
# ## CNN(画像＋テーブル)

# %% [markdown]
# __version__

# %% [markdown]
# __ver1__<br>
# train_concat&メタデータ込み：CV:0.974, LB:????<br>
# __ver2__<br>
# 256*256：CV:0.885, LB:0.890<br>
# __verSN:1__<br>
# metaval:resizeのみ<br>
# 192_192：OOF: 0.869 Wall time:  1h 33min LB: 0.861<br>
# 224_224：OOF: 0.883 Wall time:  2h 07min LB: 0.862<br>
# 256_256：OOF: 0.875 Wall time:  2h 36min LB: 0.882<br>
# 382_382：OOF: 0.869 Wall time:  5h 10min LB: 0.854<br>
# 512_512：OOF: 0.848 Wall time: 10h 29min LB: 0.852<br>
# __verSN:2__<br>
# metaval:metaの組み込み<br>
# 64_64  ：OOF: 0.856 Wall time: 20min 50s LB: 0.852<br>
# 256_256：OOF: 0.874 Wall time: 2h 31min 55s LB: 0.885<br>
# __verSN:3__<br>
# stackingに切り替え<br>
# 64_64  ：OOF: 0.876 Wall time: 30min 59s    LB: 0.8779<br>
# 128_128：OOF: 0.881 Wall time: about 50min  LB: 0.8756<br>
# 192_192：OOF: 0.893 Wall time: 2h 10min 17s LB: 0.8813<br>
# 224_224：OOF: 0.892 Wall time: 2h 41min 8s  LB: 0.8807<br>
# 256_256：OOF: 0.897 Wall time: 3h 24min 25s LB: 0.8760<br>
# 384_384：OOF: 0.872 Wall time: 7h 26min 48s LB: 0.8676<br>
# __verSN:4__<br>
# tfrecordによるfold + epoch20<br>
# 64_64  ：OOF: 0.873 Wall time: 38min 15s    LB:0.8856 <br>
# 96_96  ：OOF: 0.879 Wall time: 54min 34s    LB:0.8719 <br>
# 128_128：OOF: 0.882 Wall time: 1h 20min 49s LB:0.8929 <br>
# 160_160：OOF: 0.884 Wall time: 2h 8min 24s  LB:0.8678 <br>
# 192_192：OOF: 0.885 Wall time: 不明         LB:0.8704 <br>
# __verSN:5__<br>
# 2019データ<br>
# 64_64  ：OOF: 0.903 Wall time: 30min 37s    LB:0.7135 <br>
# 128_128：OOF: 0.924 Wall time: 不明         LB:0.7449 <br>
# __verSN:6__<br>
# train + malignant2019 merge<br>
# 64_64  ：OOF: 0.821 Wall time: 24min 19s    LB:0.8924 <br>
# 128_128：OOF: 0.891 Wall time: 1h 12min 48s LB:0.8891 <br>
# 256_256：OOF: 0.900 Wall time: 4h 19min 32s LB:0.8857 <br>
# __verSN:7__<br>
# train + malignant2019 merge → BGR2GRAY<br>
# 64_64  ：OOF: 0.812 Wall time: 27min        LB:0.8396 <br>
# 128_128：OOF: 0.889 Wall time: 1h 5min 16s  LB:0.8633 <br>
# 256_256：OOF: 0.897 Wall time: 3h 44min 52s LB:0.8523 <br>
# __verSN:8__<br>
# pad BGR2GRAY<br>
# 64_64  ：OOF: 0.948 Wall time: 28min        LB:0.8758 <br>
# 128_128：OOF: 0.959 Wall time: 1h 9min 39s  LB:0.8898 <br>
# 256_256：OOF: 0.960 Wall time: 4h 37min 32s LB:0.9037★ <br>
# __verSN:9__<br>
# pad ROTATE_90<br>
# 64_64  ：OOF: 0.948 Wall time: 33min 23s    LB:0.8765 <br>
# 128_128：OOF: 0.955 Wall time: 1h 13min 50s LB:0.8972 <br>
# 256_256：OOF: 0.960 Wall time: 4h 35min 39s LB:0.8690 <br>
# __verSN:9__<br>
# train_roman<br>
# 256_256：OOF: 0.976 Wall time: 5h 26min 26s LB:0.8339 <br>
# __verSN:10__<br>
# TTA: 公式testfile + ROTATE_270 + ROTATE_90<br>
# 256_256 pad BGR2GRAY：OOF: ???? Wall time: 5h 26min 26s LB:???? <br>
# 256_256 TrainRoman  ：OOF: ???? Wall time: 5h 26min 26s LB:???? <br>
# __verSN:11__<br>
# centerCrop + shades of Gray color constancy<br>
# 64_64  ：OOF: 0.865 Wall time: 16min 23s    LB:0.8800 <br>
# 224_224：OOF: 0.880 Wall time: 2h 2min 17s  LB:0.9058★ <br>
# __verSN:12__<br>
# model architect<br>
# 224_224：OOF: 0.859 Wall time: 2h 4min 39s  LB:0.8987 <br>
# 256_256：OOF: 0.856 Wall time: 4h 29min 11s  LB:0.8534 <br>
# __verSN:13__<br>
# model architect(ニューロンを尻すぼみにする)<br>
# 224_224(patientid有り)：OOF: 0.859 Wall time: 1h 28min 11s  LB:0.9119 <br>
# 224_224(patientid無し)：OOF: 0.861 Wall time: 1h 31min  9s  LB:0.9048 <br>

# %%
# At least fixing some random seeds. 
# It is still impossible to make results 100% reproducible when using GPU
warnings.simplefilter('ignore')
torch.manual_seed(47)
np.random.seed(47)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class MelanomaDataset(Dataset):
    def __init__(self, df: pd.DataFrame, imfolder: str, train: bool = True, 
                 transforms = None,  meta_features = None):
        """
        Class initialization
        Args:
            df (pd.DataFrame): DataFrame with data description→学習に使わない
            imfolder (str): folder with images
            train (bool): flag of whether a training dataset is being initialized or testing one
            transforms: image transformation method to be applied
            meta_features (list): list of features with meta information, such as sex and age
            
        """
        self.df = df
        self.imfolder = imfolder
        self.transforms = transforms
        self.train = train
        self.meta_features = meta_features
        
    def __getitem__(self, index):
        im_path = os.path.join(self.imfolder, self.df.iloc[index]['image_name'] + '.jpg')
        x = cv2.imread(im_path)
        meta = np.array(self.df.iloc[index][self.meta_features].values, dtype=np.float32)

        if self.transforms:
            x = self.transforms(x)
            
        if self.train:
            y = self.df.loc[index]['target']
            return (x, meta), y
        else:
            return (x, meta)
            #return x
    
    def __len__(self):
        return len(self.df)
    
    
class Net(nn.Module):
    def __init__(self, arch, n_meta_features: int):
        super(Net, self).__init__()
       
        #Cnn part
        self.arch = arch
        #numCnnFtr = self.arch._fc.in_features
        numCnnFtr = 1000
        
        #meta part
        self.meta = nn.Sequential(nn.Linear(n_meta_features, 512),
                                  nn.BatchNorm1d(512),
                                  nn.ReLU(),
                                  nn.Dropout(p=0.2),
                                  nn.Linear(512, 256),  # FC layer output will have 50 features
                                  nn.BatchNorm1d(256),
                                  nn.ReLU(),
                                  nn.Dropout(p=0.2))
        
        #full connected part
        self.metaAfter = nn.Sequential(nn.Linear(256 + numCnnFtr, 1024),
                                       nn.BatchNorm1d(1024),
                                       nn.ReLU())
        self.fc = nn.Linear(1024, 1) 
        
    def forward(self, inputs):
        """
        No sigmoid in forward because we are going to use BCEWithLogitsLoss
        Which applies sigmoid for us when calculating a loss
        """
        x, meta = inputs
        cnn_features = self.arch(x)
        meta_features = self.meta(meta)
        #print(cnn_features.shape) #1000
        #print(meta_features.shape)#256
        features = torch.cat((cnn_features, meta_features), dim=1)
        features = self.metaAfter(features)
        output = self.fc(features)
        return output

# %%
train_transform = transforms.Compose([
    #transforms.RandomResizedCrop(size=224, scale=(0.7, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=32. / 255.,saturation=0.5),
    transforms.Cutout(scale=(0.05, 0.007), value=(0, 0)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
])
test_transform = transforms.Compose([
    #transforms.RandomResizedCrop(size=224, scale=(0.7, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=32. / 255.,saturation=0.5),
    transforms.Cutout(scale=(0.05, 0.007), value=(0, 0)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
])

# %%
def TableDataPreprocess2020(dt):
    # One-hot encoding of anatom_site_general_challenge feature
    concat = pd.concat([dt[0]['anatom_site_general_challenge'], dt[1]['anatom_site_general_challenge']], ignore_index=True)
    dummies = pd.get_dummies(concat, dummy_na=True, dtype=np.uint8, prefix='site')
    dt[0] = pd.concat([dt[0], dummies.iloc[:dt[0].shape[0]]], axis=1)
    dt[1] = pd.concat([dt[1], dummies.iloc[dt[0].shape[0]:].reset_index(drop=True)], axis=1)
    for df in dt:
        df['sex'] = df['sex'].map({'male': 1, 'female': 0})
        df['sex'] = df['sex'].fillna(-1)
        df['age_approx'] /= df['age_approx'].max()
        df['age_approx'] = df['age_approx'].fillna(0)
        df['patient_id'] = df['patient_id'].fillna(0)
        df = df.drop(['patient_id'], axis=1)
    return dt

def TableDataPreprocess2019(dt):
    # One-hot encoding of anatom_site_general_challenge feature
    concat = pd.concat([dt[0]['anatom_site_general_challenge'], dt[1]['anatom_site_general_challenge']], ignore_index=True)
    dummies = pd.get_dummies(concat, dummy_na=True, dtype=np.uint8, prefix='site')
    dt[0] = pd.concat([dt[0], dummies.iloc[:dt[0].shape[0]]], axis=1)
    dt[1] = pd.concat([dt[1], dummies.iloc[dt[0].shape[0]:].reset_index(drop=True)], axis=1)
    for df in dt:
        df['sex'] = df['sex'].map({'male': 1, 'female': 0})
        df['sex'] = df['sex'].fillna(-1)
        df['age_approx'] /= df['age_approx'].max()
        df['age_approx'] = df['age_approx'].fillna(0)
    return dt

# %%
def Exec_TTAmod(epochs, model_path, es_patience, bat_size, train_df, test_df, test_imfolder, arch, tfrecord = None):
    
    meta_features = ['sex', 'age_approx'] + [col for col in train_df.columns if 'site_' in col]
    meta_features.remove('anatom_site_general_challenge')
    
    #sample_sub_metaval_stacking.csv用Imagename
    ImgNm = train_df[['image_name']]
    
    oof = np.zeros((len(train_df), 1))  # Out Of Fold predictions
    test_preds = torch.zeros((len(test_df), 1), dtype=torch.float32, device=device)  # Predictions for test set
    
    # We stratify by target value, thus, according to sklearn StratifiedKFold documentation
    # We can fill `X` with zeroes of corresponding length to use it as a placeholder
    # since we only need `y` to stratify the data
    # for fold, (train_idx, val_idx) in enumerate(skf.split(X=np.zeros(len(train_df)), y=train_df['target']), 1):
    for fold, (train_idx, val_idx) in enumerate(skf.split(X=np.zeros(len(train_df)), y=train_df['target'], groups=tfrecord['tfrecord'].tolist()), 1):
    #for fold, (train_idx, val_idx) in enumerate(skf.split(X=np.zeros(len(train_df)), y=train_df['target'], groups=train_df['patient_id'].tolist()), 1):
        print('=' * 20, 'Fold', fold, '=' * 20)
        
        best_val = None  # Best validation score within this fold
        patience = es_patience  # Current patience counter
        model = Net(arch=arch, n_meta_features=len(meta_features))  # New model for each fold
        model = model.to(device)
        
        
        optim = torch.optim.Adam(model.parameters(), lr=0.001)
        scheduler = ReduceLROnPlateau(optimizer=optim, mode='max', patience=1, verbose=True, factor=0.2)
        criterion = nn.BCEWithLogitsLoss()
        
        train = MelanomaDataset(df=train_df.iloc[train_idx].reset_index(drop=True),  
                                imfolder = SIIM_ISIC_Melanoma_Classification + train_folder, 
                                train=True, 
                                transforms=train_transform,
                                meta_features=meta_features)
        val = MelanomaDataset(df=train_df.iloc[val_idx].reset_index(drop=True),
                              imfolder = SIIM_ISIC_Melanoma_Classification + train_folder,
                              train=True,
                              transforms=test_transform,
                              meta_features=meta_features)
    
        train_loader = DataLoader(dataset=train, batch_size=bat_size[0], shuffle=True, num_workers=2)
        val_loader = DataLoader(dataset=val, batch_size=bat_size[1], shuffle=False, num_workers=2)
        
        del train, val
        gc.collect()
        
        for epoch in range(epochs):
            start_time = time.time()
            correct = 0
            epoch_loss = 0
            model.train()
            
            for x, y in train_loader:
                x[0] = torch.tensor(x[0], device=device, dtype=torch.float32)
                x[1] = torch.tensor(x[1], device=device, dtype=torch.float32)
                y = torch.tensor(y, device=device, dtype=torch.float32)
                
                
                optim.zero_grad()
                z = model(x)
                loss = criterion(z, y.unsqueeze(1))
                loss.backward()
                optim.step()
                pred = torch.round(torch.sigmoid(z))  # round off sigmoid to obtain predictions
                correct += (pred.cpu() == y.cpu().unsqueeze(1)).sum().item()  # tracking number of correctly predicted samples
                epoch_loss += loss.item()
    
                
            train_acc = correct / len(train_idx)
    
            model.eval()  # switch model to the evaluation mode
            val_preds = torch.zeros((len(val_idx), 1), dtype=torch.float32, device=device)
            with torch.no_grad():  # Do not calculate gradient since we are only predicting
                # Predicting on validation set
                for j, (x_val, y_val) in enumerate(val_loader):
                    x_val[0] = torch.tensor(x_val[0], device=device, dtype=torch.float32)
                    x_val[1] = torch.tensor(x_val[1], device=device, dtype=torch.float32)
                    y_val = torch.tensor(y_val, device=device, dtype=torch.float32)
                    z_val = model(x_val)
                    val_pred = torch.sigmoid(z_val)
                    val_preds[j*x_val[0].shape[0]:j*x_val[0].shape[0] + x_val[0].shape[0]] = val_pred
                val_acc = accuracy_score(train_df.iloc[val_idx]['target'].values, torch.round(val_preds.cpu()))
                val_roc = roc_auc_score(train_df.iloc[val_idx]['target'].values, val_preds.cpu())
                
                print('Epoch {:03}: | Loss: {:.3f} | Train acc: {:.3f} | Val acc: {:.3f} | Val roc_auc: {:.3f} | Training time: {}'.format(
                epoch + 1, 
                epoch_loss, 
                train_acc, 
                val_acc, 
                val_roc, 
                str(datetime.timedelta(seconds=time.time() - start_time))[:7]))
                
                scheduler.step(val_roc)
                # During the first iteration (first epoch) best validation is set to None
                if not best_val:
                    best_val = val_roc  # So any validation roc_auc we have is the best one for now
                    torch.save(model, model_path)  # Saving the model
                    continue
                    
                if val_roc >= best_val:
                    best_val = val_roc
                    patience = es_patience  # Resetting patience since we have new best validation accuracy
                    torch.save(model, model_path)  # Saving current best model
                else:
                    patience -= 1
                    if patience == 0:
                        print('Early stopping. Best Val roc_auc: {:.3f}'.format(best_val))
                        break
        
        del train_loader, x, y
        gc.collect()
        
        model = torch.load(model_path)  # Loading best model of this fold
        model.eval()  # switch model to the evaluation mode
        val_preds = torch.zeros((len(val_idx), 1), dtype=torch.float32, device=device)
        
        with torch.no_grad():
            # Predicting on validation set once again to obtain data for OOF
            #for _ in range(TTA):
            for j, (x_val, y_val) in enumerate(val_loader):
                x_val[0] = torch.tensor(x_val[0], device=device, dtype=torch.float32)
                x_val[1] = torch.tensor(x_val[1], device=device, dtype=torch.float32)
                y_val = torch.tensor(y_val, device=device, dtype=torch.float32)
                z_val = model(x_val)
                val_pred = torch.sigmoid(z_val)
                val_preds[j*x_val[0].shape[0]:j*x_val[0].shape[0] + x_val[0].shape[0]] = val_pred
            #val_preds /= TTA
            oof[val_idx] = val_preds.cpu()
            del val_loader, x_val, y_val
            gc.collect()
            
            # Predicting on test set
            test_preds_tmp = torch.zeros((len(test_df), 1), dtype=torch.float32, device=device)
            for pth in test_imfolder:
                test = MelanomaDataset(df=test_df,
                                       imfolder = pth, 
                                       train=False,
                                       transforms=test_transform,
                                       meta_features=meta_features)
                test_loader = DataLoader(dataset=test, batch_size=bat_size[2], shuffle=False, num_workers=2)
                
                for i, x_test in enumerate(test_loader):
                    x_test[0] = torch.tensor(x_test[0], device=device, dtype=torch.float32)
                    x_test[1] = torch.tensor(x_test[1], device=device, dtype=torch.float32)
                    z_test = model(x_test)
                    z_test = torch.sigmoid(z_test)
                    test_preds_tmp[i*x_test[0].shape[0]:i*x_test[0].shape[0] + x_test[0].shape[0]] += z_test
                
                del test_loader, x_test, z_test
                gc.collect()
            
            test_preds_tmp /= len(test_imfolder)
            test_preds = test_preds + test_preds_tmp
            
            del test_preds_tmp
            
    test_preds /= skf.n_splits
    
    print('OOF: {:.3f}'.format(roc_auc_score(train_df['target'], oof)))
    
    return test_preds, oof, ImgNm

# %%
def initData2020(Pre = None):
    #train(train+2019malig)
    train_malig = pd.read_csv(SIIM_ISIC_Melanoma_Classification + "train_malig_2.csv")
    train_malig = train_malig[train_malig.tfrecord != -1]
    train_malig = train_malig.drop(['diagnosis', 'benign_malignant', 'width', 'height', 'source', 'ext'], axis=1)
    train_malig = train_malig.reset_index(drop=True)
    tfrecord_malig = train_malig.loc[:,['tfrecord']]
    tfrecord_malig = tfrecord_malig-15
    
    
    train_df = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'train.csv')
    train_df = train_df.drop(['diagnosis','benign_malignant'], axis=1)
    train_df = train_df[train_df.tfrecord != -1]
    train_df = train_df.drop(['width','height','patient_code'], axis=1)
    train_df = train_df.reset_index(drop=True)
    tfrecord = train_df.loc[:,['tfrecord']]
    
    #concate(train+2019malig)
    train_df = pd.concat([train_df, train_malig], axis=0)
    train_df = train_df.reset_index(drop=True)
    
    #padding (malignantOnly)
    #train_pad = train_df[train_df.target == 1]
    #train_pad = train_pad.reset_index(drop=True)
    #train_pad[['image_name']] = Pre + '_' + train_pad[['image_name']]
    #tfrecord_pad = train_pad.loc[:,['tfrecord']]
    
    #concate(train+2019malig) + BGR2GRAY(malignantOnly)
    #train_df = pd.concat([train_df, train_pad], axis=0)
    
    #tfrecord concate
    train_df = train_df.drop(['tfrecord'], axis=1)
    train_df = train_df.reset_index(drop=True)
    #tfrecord = pd.concat([tfrecord, tfrecord_malig, tfrecord_pad], axis=0)
    tfrecord = pd.concat([tfrecord, tfrecord_malig], axis=0)
    tfrecord = tfrecord.reset_index(drop=True)
    
    
    #test
    test_df = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'test.csv')
    
    return train_df, test_df, tfrecord

def initData2019():
    train_df = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'train_2019year.csv')
    train_df = train_df.drop(['diagnosis','benign_malignant'], axis=1)
    train_df = train_df[train_df.tfrecord != -1]
    train_df = train_df.drop(['width','height'], axis=1) 

    train_df = train_df.reset_index(drop=True)
    tfrecord = train_df.loc[:,['tfrecord']]
    train_df = train_df.drop(['tfrecord'], axis=1)
    
    test_df = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'test.csv')
    
    train_df = train_df.drop(['patient_id'], axis=1)
    test_df = test_df.drop(['patient_id'], axis=1)
    
    return train_df, test_df, tfrecord

# %%
# %%time
#224_224_GrayColorConstancy
arch = EfficientNet.from_pretrained('efficientnet-b0')  # Going to use efficientnet-b0 NN architecture
#EfficientNet.from_pretrained('efficientnet-b0',num_classes=targetのクラス数（今回だと2?）) 
skf = GroupKFold(n_splits=5)
model_name = "224_224_GrayColorConstancy"
train_folder = "pad_jpg/train/" + model_name
epochs = 20  # Number of epochs to run
model_path =  Output + 'model/model_' + model_name + '.pth'  # Path and filename to save model to
es_patience = 3  # Early Stopping patience - for how many epochs with no improvements to wait
bat_size = [64, 32, 16] #train, val, test
test_imfolder = [SIIM_ISIC_Melanoma_Classification + "pad_jpg/test/" + model_name]

#データ整形
train_df, test_df, tfrecord = initData2020()
dt = [train_df, test_df]
[train_df, test_df] = TableDataPreprocess2020(dt)


#実行
test_preds, metaval_preds, metaval_ID = Exec_TTAmod(epochs, model_path, es_patience, bat_size, train_df, test_df, 
                                                    test_imfolder, arch, tfrecord)

sns.kdeplot(pd.Series(test_preds.cpu().numpy().reshape(-1,)));
sns.kdeplot(pd.Series(metaval_preds.reshape(-1,)));

#test用
test_ID = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'sample_submission.csv')
test_ID['target'] = test_preds.cpu().numpy().reshape(-1,)
test_ID.to_csv(Output + 'test/sub_test_stacking_' + model_name + '.csv', index=False)

#metaval用
#metaval_ID = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'sample_sub_metaval_stacking.csv')
metaval_ID.loc[:,"target"] = 0
metaval_ID['target'] = metaval_preds.reshape(-1,)
metaval_ID.to_csv(Output + 'metaval/sub_metaval_stacking_' + model_name + '.csv', index=False)

#test用submit
api = KaggleApi()
api.authenticate()  # 認証を通す
csv_file_path = Output + 'test/sub_test_stacking_' + model_name + '.csv'
message = 'Imgprocessing Stacking' + model_name
competition_id = 'siim-isic-melanoma-classification'
api.competition_submit(csv_file_path, message, competition_id)
# Out:
# Loaded pretrained weights for efficientnet-b0
# ==================== Fold 1 ====================

# %%
# %%time
#224_224_GrayColorConstancy
arch = EfficientNet.from_pretrained('efficientnet-b0')  # Going to use efficientnet-b0 NN architecture
#EfficientNet.from_pretrained('efficientnet-b0',num_classes=targetのクラス数（今回だと2?）) 
skf = GroupKFold(n_splits=5)
model_name = "224_224_GrayColorConstancy"
train_folder = "pad_jpg/train/" + model_name
epochs = 20  # Number of epochs to run
model_path =  Output + 'model/model_' + model_name + '.pth'  # Path and filename to save model to
es_patience = 3  # Early Stopping patience - for how many epochs with no improvements to wait
bat_size = [64, 32, 16] #train, val, test
test_imfolder = [SIIM_ISIC_Melanoma_Classification + "pad_jpg/test/" + model_name]

#データ整形
train_df, test_df, tfrecord = initData2020()
dt = [train_df, test_df]
[train_df, test_df] = TableDataPreprocess2020(dt)


#実行
test_preds, metaval_preds, metaval_ID = Exec_TTAmod(epochs, model_path, es_patience, bat_size, train_df, test_df, 
                                                    test_imfolder, arch, tfrecord)

sns.kdeplot(pd.Series(test_preds.cpu().numpy().reshape(-1,)));
sns.kdeplot(pd.Series(metaval_preds.reshape(-1,)));

#test用
test_ID = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'sample_submission.csv')
test_ID['target'] = test_preds.cpu().numpy().reshape(-1,)
test_ID.to_csv(Output + 'test/sub_test_stacking_' + model_name + '.csv', index=False)

#metaval用
#metaval_ID = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'sample_sub_metaval_stacking.csv')
metaval_ID.loc[:,"target"] = 0
metaval_ID['target'] = metaval_preds.reshape(-1,)
metaval_ID.to_csv(Output + 'metaval/sub_metaval_stacking_' + model_name + '.csv', index=False)

#test用submit
api = KaggleApi()
api.authenticate()  # 認証を通す
csv_file_path = Output + 'test/sub_test_stacking_' + model_name + '.csv'
message = 'Imgprocessing Stacking' + model_name
competition_id = 'siim-isic-melanoma-classification'
api.competition_submit(csv_file_path, message, competition_id)
# Out:
# Loaded pretrained weights for efficientnet-b0
# ==================== Fold 1 ====================
# Epoch 001: | Loss: 46.381 | Train acc: 0.966 | Val acc: 0.970 | Val roc_auc: 0.864 | Training time: 0:02:13
# Epoch 002: | Loss: 39.651 | Train acc: 0.973 | Val acc: 0.972 | Val roc_auc: 0.825 | Training time: 0:02:13
# Epoch 003: | Loss: 35.755 | Train acc: 0.974 | Val acc: 0.976 | Val roc_auc: 0.919 | Training time: 0:02:13
# Epoch 004: | Loss: 33.147 | Train acc: 0.977 | Val acc: 0.974 | Val roc_auc: 0.908 | Training time: 0:02:13
# Epoch 005: | Loss: 31.590 | Train acc: 0.977 | Val acc: 0.976 | Val roc_auc: 0.923 | Training time: 0:02:13
# Epoch 006: | Loss: 32.127 | Train acc: 0.977 | Val acc: 0.974 | Val roc_auc: 0.915 | Training time: 0:02:13
# Epoch 007: | Loss: 30.460 | Train acc: 0.977 | Val acc: 0.966 | Val roc_auc: 0.908 | Training time: 0:02:13
# Epoch     7: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 008: | Loss: 24.172 | Train acc: 0.980 | Val acc: 0.978 | Val roc_auc: 0.929 | Training time: 0:02:13
# Epoch 009: | Loss: 21.054 | Train acc: 0.983 | Val acc: 0.978 | Val roc_auc: 0.932 | Training time: 0:02:13
# Epoch 010: | Loss: 19.404 | Train acc: 0.984 | Val acc: 0.977 | Val roc_auc: 0.927 | Training time: 0:02:13
# Epoch 011: | Loss: 18.508 | Train acc: 0.985 | Val acc: 0.979 | Val roc_auc: 0.931 | Training time: 0:02:13
# Epoch    11: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 012: | Loss: 14.682 | Train acc: 0.988 | Val acc: 0.976 | Val roc_auc: 0.934 | Training time: 0:02:13
# Epoch 013: | Loss: 13.818 | Train acc: 0.989 | Val acc: 0.974 | Val roc_auc: 0.933 | Training time: 0:02:13
# Epoch 014: | Loss: 12.865 | Train acc: 0.989 | Val acc: 0.976 | Val roc_auc: 0.936 | Training time: 0:02:13
# Epoch 015: | Loss: 12.094 | Train acc: 0.989 | Val acc: 0.978 | Val roc_auc: 0.935 | Training time: 0:02:13
# Epoch 016: | Loss: 11.269 | Train acc: 0.990 | Val acc: 0.976 | Val roc_auc: 0.932 | Training time: 0:02:13
# Epoch    16: reducing learning rate of group 0 to 8.0000e-06.
# Epoch 017: | Loss: 10.703 | Train acc: 0.991 | Val acc: 0.976 | Val roc_auc: 0.935 | Training time: 0:02:13
# Early stopping. Best Val roc_auc: 0.936
# ==================== Fold 2 ====================
# Epoch 001: | Loss: 33.429 | Train acc: 0.975 | Val acc: 0.970 | Val roc_auc: 0.815 | Training time: 0:02:13
# Epoch 002: | Loss: 27.566 | Train acc: 0.980 | Val acc: 0.973 | Val roc_auc: 0.823 | Training time: 0:02:12
# Epoch 003: | Loss: 26.407 | Train acc: 0.980 | Val acc: 0.973 | Val roc_auc: 0.819 | Training time: 0:02:13
# Epoch 004: | Loss: 25.243 | Train acc: 0.981 | Val acc: 0.971 | Val roc_auc: 0.818 | Training time: 0:02:12
# Epoch     4: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 005: | Loss: 19.039 | Train acc: 0.984 | Val acc: 0.975 | Val roc_auc: 0.832 | Training time: 0:02:12
# Epoch 006: | Loss: 15.243 | Train acc: 0.988 | Val acc: 0.973 | Val roc_auc: 0.831 | Training time: 0:02:13
# Epoch 007: | Loss: 13.534 | Train acc: 0.989 | Val acc: 0.973 | Val roc_auc: 0.831 | Training time: 0:02:12
# Epoch     7: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 008: | Loss: 10.472 | Train acc: 0.991 | Val acc: 0.974 | Val roc_auc: 0.838 | Training time: 0:02:13
# Epoch 009: | Loss: 10.140 | Train acc: 0.992 | Val acc: 0.974 | Val roc_auc: 0.833 | Training time: 0:02:13
# Epoch 010: | Loss: 9.544 | Train acc: 0.992 | Val acc: 0.975 | Val roc_auc: 0.832 | Training time: 0:02:13
# Epoch    10: reducing learning rate of group 0 to 8.0000e-06.
# Epoch 011: | Loss: 8.635 | Train acc: 0.993 | Val acc: 0.974 | Val roc_auc: 0.834 | Training time: 0:02:13
# Early stopping. Best Val roc_auc: 0.838
# ==================== Fold 3 ====================
# Epoch 001: | Loss: 26.475 | Train acc: 0.979 | Val acc: 0.953 | Val roc_auc: 0.854 | Training time: 0:02:13
# Epoch 002: | Loss: 21.252 | Train acc: 0.984 | Val acc: 0.972 | Val roc_auc: 0.851 | Training time: 0:02:13
# Epoch 003: | Loss: 22.540 | Train acc: 0.982 | Val acc: 0.974 | Val roc_auc: 0.807 | Training time: 0:02:13
# Epoch     3: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 004: | Loss: 16.718 | Train acc: 0.986 | Val acc: 0.976 | Val roc_auc: 0.853 | Training time: 0:02:12
# Early stopping. Best Val roc_auc: 0.854
# ==================== Fold 4 ====================
# Epoch 001: | Loss: 25.054 | Train acc: 0.981 | Val acc: 0.956 | Val roc_auc: 0.855 | Training time: 0:02:13
# Epoch 002: | Loss: 19.982 | Train acc: 0.985 | Val acc: 0.975 | Val roc_auc: 0.852 | Training time: 0:02:13
# Epoch 003: | Loss: 18.878 | Train acc: 0.985 | Val acc: 0.975 | Val roc_auc: 0.851 | Training time: 0:02:14
# Epoch     3: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 004: | Loss: 12.097 | Train acc: 0.990 | Val acc: 0.979 | Val roc_auc: 0.859 | Training time: 0:02:13
# Epoch 005: | Loss: 8.953 | Train acc: 0.993 | Val acc: 0.977 | Val roc_auc: 0.858 | Training time: 0:02:13
# Epoch 006: | Loss: 7.085 | Train acc: 0.994 | Val acc: 0.978 | Val roc_auc: 0.854 | Training time: 0:02:13
# Epoch     6: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 007: | Loss: 6.236 | Train acc: 0.995 | Val acc: 0.979 | Val roc_auc: 0.859 | Training time: 0:02:13
# Epoch 008: | Loss: 6.510 | Train acc: 0.995 | Val acc: 0.980 | Val roc_auc: 0.859 | Training time: 0:02:13
# Epoch 009: | Loss: 5.899 | Train acc: 0.995 | Val acc: 0.980 | Val roc_auc: 0.860 | Training time: 0:02:13
# Epoch 010: | Loss: 4.912 | Train acc: 0.996 | Val acc: 0.979 | Val roc_auc: 0.858 | Training time: 0:02:13
# Epoch 011: | Loss: 4.862 | Train acc: 0.996 | Val acc: 0.980 | Val roc_auc: 0.861 | Training time: 0:02:13
# Epoch 012: | Loss: 4.824 | Train acc: 0.996 | Val acc: 0.979 | Val roc_auc: 0.860 | Training time: 0:02:13
# Epoch 013: | Loss: 4.441 | Train acc: 0.996 | Val acc: 0.979 | Val roc_auc: 0.862 | Training time: 0:02:13
# Epoch 014: | Loss: 4.520 | Train acc: 0.997 | Val acc: 0.979 | Val roc_auc: 0.857 | Training time: 0:02:13
# Epoch 015: | Loss: 3.693 | Train acc: 0.997 | Val acc: 0.980 | Val roc_auc: 0.860 | Training time: 0:02:13
# Epoch    15: reducing learning rate of group 0 to 8.0000e-06.
# Epoch 016: | Loss: 3.943 | Train acc: 0.997 | Val acc: 0.980 | Val roc_auc: 0.859 | Training time: 0:02:15
# Early stopping. Best Val roc_auc: 0.862
# ==================== Fold 5 ====================
# Epoch 001: | Loss: 17.156 | Train acc: 0.986 | Val acc: 0.977 | Val roc_auc: 0.867 | Training time: 0:02:13
# Epoch 002: | Loss: 15.968 | Train acc: 0.987 | Val acc: 0.979 | Val roc_auc: 0.868 | Training time: 0:02:13
# Epoch 003: | Loss: 14.609 | Train acc: 0.988 | Val acc: 0.973 | Val roc_auc: 0.854 | Training time: 0:02:13
# Epoch 004: | Loss: 13.851 | Train acc: 0.988 | Val acc: 0.973 | Val roc_auc: 0.870 | Training time: 0:02:13
# Epoch 005: | Loss: 13.876 | Train acc: 0.988 | Val acc: 0.975 | Val roc_auc: 0.863 | Training time: 0:02:13
# Epoch 006: | Loss: 11.585 | Train acc: 0.991 | Val acc: 0.973 | Val roc_auc: 0.851 | Training time: 0:02:13
# Epoch     6: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 007: | Loss: 8.100 | Train acc: 0.993 | Val acc: 0.979 | Val roc_auc: 0.868 | Training time: 0:02:13
# Early stopping. Best Val roc_auc: 0.870
# OOF: 0.859
# 100%|██████████| 274k/274k [00:03<00:00, 78.1kB/s]
# CPU times: user 1h 21min 47s, sys: 36min 3s, total: 1h 57min 51s
# Wall time: 2h 4min 39s
# Successfully submitted to SIIM-ISIC Melanoma Classification

# %%
# %%time
#256_256_GrayColorConstancy
arch = EfficientNet.from_pretrained('efficientnet-b1')  # Going to use efficientnet-b0 NN architecture
#EfficientNet.from_pretrained('efficientnet-b0',num_classes=targetのクラス数（今回だと2?）) 
skf = GroupKFold(n_splits=5)
model_name = "256_256_GrayColorConstancy"
train_folder = "pad_jpg/train/" + model_name
epochs = 20  # Number of epochs to run
model_path =  Output + 'model/model_' + model_name + '.pth'  # Path and filename to save model to
es_patience = 3  # Early Stopping patience - for how many epochs with no improvements to wait
bat_size = [32, 16, 16] #train, val, test
test_imfolder = [SIIM_ISIC_Melanoma_Classification + "pad_jpg/test/" + model_name]

#データ整形
train_df, test_df, tfrecord = initData2020()
dt = [train_df, test_df]
[train_df, test_df] = TableDataPreprocess2020(dt)


#実行
test_preds, metaval_preds, metaval_ID = Exec_TTAmod(epochs, model_path, es_patience, bat_size, train_df, test_df, 
                                                    test_imfolder, arch, tfrecord)

sns.kdeplot(pd.Series(test_preds.cpu().numpy().reshape(-1,)));
sns.kdeplot(pd.Series(metaval_preds.reshape(-1,)));

#test用
test_ID = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'sample_submission.csv')
test_ID['target'] = test_preds.cpu().numpy().reshape(-1,)
test_ID.to_csv(Output + 'test/sub_test_stacking_' + model_name + '.csv', index=False)

#metaval用
#metaval_ID = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'sample_sub_metaval_stacking.csv')
metaval_ID.loc[:,"target"] = 0
metaval_ID['target'] = metaval_preds.reshape(-1,)
metaval_ID.to_csv(Output + 'metaval/sub_metaval_stacking_' + model_name + '.csv', index=False)

#test用submit
api = KaggleApi()
api.authenticate()  # 認証を通す
csv_file_path = Output + 'test/sub_test_stacking_' + model_name + '.csv'
message = 'Imgprocessing Stacking' + model_name
competition_id = 'siim-isic-melanoma-classification'
api.competition_submit(csv_file_path, message, competition_id)
# Out:
# Loaded pretrained weights for efficientnet-b1
# ==================== Fold 1 ====================
# Epoch 001: | Loss: 107.381 | Train acc: 0.965 | Val acc: 0.971 | Val roc_auc: 0.780 | Training time: 0:04:00
# Epoch 002: | Loss: 96.291 | Train acc: 0.969 | Val acc: 0.970 | Val roc_auc: 0.784 | Training time: 0:04:00
# Epoch 003: | Loss: 89.950 | Train acc: 0.970 | Val acc: 0.971 | Val roc_auc: 0.851 | Training time: 0:04:00
# Epoch 004: | Loss: 96.906 | Train acc: 0.969 | Val acc: 0.971 | Val roc_auc: 0.848 | Training time: 0:04:00
# Epoch 005: | Loss: 94.585 | Train acc: 0.970 | Val acc: 0.971 | Val roc_auc: 0.836 | Training time: 0:04:00
# Epoch     5: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 006: | Loss: 89.734 | Train acc: 0.970 | Val acc: 0.972 | Val roc_auc: 0.853 | Training time: 0:04:00
# Epoch 007: | Loss: 87.625 | Train acc: 0.970 | Val acc: 0.971 | Val roc_auc: 0.823 | Training time: 0:04:00
# Epoch 008: | Loss: 88.094 | Train acc: 0.970 | Val acc: 0.956 | Val roc_auc: 0.854 | Training time: 0:04:00
# Epoch 009: | Loss: 85.331 | Train acc: 0.971 | Val acc: 0.971 | Val roc_auc: 0.850 | Training time: 0:04:00
# Epoch 010: | Loss: 85.503 | Train acc: 0.970 | Val acc: 0.971 | Val roc_auc: 0.858 | Training time: 0:04:01
# Epoch 011: | Loss: 83.831 | Train acc: 0.971 | Val acc: 0.965 | Val roc_auc: 0.864 | Training time: 0:04:02
# Epoch 012: | Loss: 83.529 | Train acc: 0.971 | Val acc: 0.973 | Val roc_auc: 0.883 | Training time: 0:04:02
# Epoch 013: | Loss: 82.116 | Train acc: 0.971 | Val acc: 0.954 | Val roc_auc: 0.870 | Training time: 0:04:02
# Epoch 014: | Loss: 80.890 | Train acc: 0.971 | Val acc: 0.972 | Val roc_auc: 0.875 | Training time: 0:04:03
# Epoch    14: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 015: | Loss: 79.837 | Train acc: 0.972 | Val acc: 0.964 | Val roc_auc: 0.876 | Training time: 0:04:03
# Early stopping. Best Val roc_auc: 0.883
# ==================== Fold 2 ====================
# Epoch 001: | Loss: 102.176 | Train acc: 0.967 | Val acc: 0.966 | Val roc_auc: 0.786 | Training time: 0:04:03
# Epoch 002: | Loss: 95.945 | Train acc: 0.970 | Val acc: 0.966 | Val roc_auc: 0.718 | Training time: 0:04:02
# Epoch 003: | Loss: 96.489 | Train acc: 0.970 | Val acc: 0.968 | Val roc_auc: 0.742 | Training time: 0:04:01
# Epoch     3: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 004: | Loss: 92.630 | Train acc: 0.971 | Val acc: 0.968 | Val roc_auc: 0.803 | Training time: 0:04:01
# Epoch 005: | Loss: 87.176 | Train acc: 0.972 | Val acc: 0.968 | Val roc_auc: 0.792 | Training time: 0:04:01
# Epoch 006: | Loss: 87.165 | Train acc: 0.971 | Val acc: 0.968 | Val roc_auc: 0.821 | Training time: 0:04:00
# Epoch 007: | Loss: 84.681 | Train acc: 0.972 | Val acc: 0.967 | Val roc_auc: 0.823 | Training time: 0:04:00
# Epoch 008: | Loss: 85.141 | Train acc: 0.971 | Val acc: 0.968 | Val roc_auc: 0.832 | Training time: 0:04:00
# Epoch 009: | Loss: 83.372 | Train acc: 0.972 | Val acc: 0.967 | Val roc_auc: 0.822 | Training time: 0:04:00
# Epoch 010: | Loss: 81.764 | Train acc: 0.972 | Val acc: 0.968 | Val roc_auc: 0.835 | Training time: 0:04:00
# Epoch 011: | Loss: 82.186 | Train acc: 0.972 | Val acc: 0.968 | Val roc_auc: 0.817 | Training time: 0:04:00
# Epoch 012: | Loss: 81.290 | Train acc: 0.972 | Val acc: 0.968 | Val roc_auc: 0.820 | Training time: 0:04:00
# Epoch    12: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 013: | Loss: 79.733 | Train acc: 0.972 | Val acc: 0.967 | Val roc_auc: 0.840 | Training time: 0:04:00
# Epoch 014: | Loss: 78.787 | Train acc: 0.973 | Val acc: 0.968 | Val roc_auc: 0.838 | Training time: 0:04:00
# Epoch 015: | Loss: 78.742 | Train acc: 0.972 | Val acc: 0.968 | Val roc_auc: 0.835 | Training time: 0:04:00
# Epoch    15: reducing learning rate of group 0 to 8.0000e-06.
# Epoch 016: | Loss: 77.891 | Train acc: 0.972 | Val acc: 0.968 | Val roc_auc: 0.835 | Training time: 0:04:00
# Early stopping. Best Val roc_auc: 0.840
# ==================== Fold 3 ====================
# Epoch 001: | Loss: 100.805 | Train acc: 0.967 | Val acc: 0.970 | Val roc_auc: 0.830 | Training time: 0:04:00
# Epoch 002: | Loss: 94.132 | Train acc: 0.970 | Val acc: 0.971 | Val roc_auc: 0.831 | Training time: 0:04:00
# Epoch 003: | Loss: 93.390 | Train acc: 0.970 | Val acc: 0.969 | Val roc_auc: 0.843 | Training time: 0:04:00
# Epoch 004: | Loss: 88.609 | Train acc: 0.971 | Val acc: 0.970 | Val roc_auc: 0.817 | Training time: 0:04:00
# Epoch 005: | Loss: 85.489 | Train acc: 0.970 | Val acc: 0.971 | Val roc_auc: 0.845 | Training time: 0:04:00
# Epoch 006: | Loss: 83.500 | Train acc: 0.971 | Val acc: 0.970 | Val roc_auc: 0.837 | Training time: 0:04:00
# Epoch 007: | Loss: 84.166 | Train acc: 0.972 | Val acc: 0.970 | Val roc_auc: 0.771 | Training time: 0:04:00
# Epoch     7: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 008: | Loss: 81.983 | Train acc: 0.971 | Val acc: 0.970 | Val roc_auc: 0.856 | Training time: 0:04:00
# Epoch 009: | Loss: 78.366 | Train acc: 0.973 | Val acc: 0.971 | Val roc_auc: 0.846 | Training time: 0:04:00
# Epoch 010: | Loss: 77.208 | Train acc: 0.973 | Val acc: 0.972 | Val roc_auc: 0.847 | Training time: 0:04:00
# Epoch    10: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 011: | Loss: 75.148 | Train acc: 0.973 | Val acc: 0.972 | Val roc_auc: 0.852 | Training time: 0:04:01
# Early stopping. Best Val roc_auc: 0.856
# ==================== Fold 4 ====================
# Epoch 001: | Loss: 95.486 | Train acc: 0.968 | Val acc: 0.968 | Val roc_auc: 0.786 | Training time: 0:04:00
# Epoch 002: | Loss: 90.691 | Train acc: 0.970 | Val acc: 0.965 | Val roc_auc: 0.838 | Training time: 0:04:00
# Epoch 003: | Loss: 86.265 | Train acc: 0.970 | Val acc: 0.968 | Val roc_auc: 0.815 | Training time: 0:04:00
# Epoch 004: | Loss: 86.176 | Train acc: 0.971 | Val acc: 0.968 | Val roc_auc: 0.835 | Training time: 0:04:00
# Epoch     4: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 005: | Loss: 78.486 | Train acc: 0.972 | Val acc: 0.969 | Val roc_auc: 0.849 | Training time: 0:04:00
# Epoch 006: | Loss: 78.304 | Train acc: 0.973 | Val acc: 0.957 | Val roc_auc: 0.830 | Training time: 0:04:00
# Epoch 007: | Loss: 78.747 | Train acc: 0.972 | Val acc: 0.970 | Val roc_auc: 0.847 | Training time: 0:04:00
# Epoch     7: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 008: | Loss: 75.362 | Train acc: 0.973 | Val acc: 0.961 | Val roc_auc: 0.840 | Training time: 0:04:00
# Early stopping. Best Val roc_auc: 0.849
# ==================== Fold 5 ====================
# Epoch 001: | Loss: 93.545 | Train acc: 0.967 | Val acc: 0.969 | Val roc_auc: 0.855 | Training time: 0:04:00
# Epoch 002: | Loss: 84.456 | Train acc: 0.971 | Val acc: 0.969 | Val roc_auc: 0.843 | Training time: 0:04:00
# Epoch 003: | Loss: 84.309 | Train acc: 0.971 | Val acc: 0.969 | Val roc_auc: 0.844 | Training time: 0:04:00
# Epoch     3: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 004: | Loss: 76.804 | Train acc: 0.973 | Val acc: 0.969 | Val roc_auc: 0.862 | Training time: 0:04:00
# Epoch 005: | Loss: 74.896 | Train acc: 0.974 | Val acc: 0.967 | Val roc_auc: 0.866 | Training time: 0:04:00
# Epoch 006: | Loss: 74.288 | Train acc: 0.974 | Val acc: 0.965 | Val roc_auc: 0.862 | Training time: 0:04:00
# Epoch 007: | Loss: 74.055 | Train acc: 0.973 | Val acc: 0.971 | Val roc_auc: 0.865 | Training time: 0:04:00
# Epoch     7: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 008: | Loss: 71.182 | Train acc: 0.975 | Val acc: 0.970 | Val roc_auc: 0.867 | Training time: 0:04:00
# Epoch 009: | Loss: 70.599 | Train acc: 0.975 | Val acc: 0.966 | Val roc_auc: 0.870 | Training time: 0:04:00
# Epoch 010: | Loss: 70.422 | Train acc: 0.975 | Val acc: 0.969 | Val roc_auc: 0.870 | Training time: 0:04:00
# Epoch 011: | Loss: 70.267 | Train acc: 0.975 | Val acc: 0.966 | Val roc_auc: 0.864 | Training time: 0:04:00
# Epoch 012: | Loss: 70.085 | Train acc: 0.976 | Val acc: 0.968 | Val roc_auc: 0.867 | Training time: 0:04:02
# Epoch    12: reducing learning rate of group 0 to 8.0000e-06.
# Epoch 013: | Loss: 70.456 | Train acc: 0.975 | Val acc: 0.968 | Val roc_auc: 0.873 | Training time: 0:04:04
# Epoch 014: | Loss: 69.917 | Train acc: 0.975 | Val acc: 0.965 | Val roc_auc: 0.866 | Training time: 0:04:11
# Epoch 015: | Loss: 69.575 | Train acc: 0.975 | Val acc: 0.965 | Val roc_auc: 0.864 | Training time: 0:04:14
# Epoch    15: reducing learning rate of group 0 to 1.6000e-06.
# Epoch 016: | Loss: 70.081 | Train acc: 0.975 | Val acc: 0.968 | Val roc_auc: 0.871 | Training time: 0:04:07
# Early stopping. Best Val roc_auc: 0.873
# OOF: 0.856
# 100%|██████████| 271k/271k [00:02<00:00, 102kB/s]
# CPU times: user 3h 16min 9s, sys: 1h 12min 48s, total: 4h 28min 58s
# Wall time: 4h 29min 11s
# Successfully submitted to SIIM-ISIC Melanoma Classification

# %%
# %%time
#224_224_GrayColorConstancy 
arch = EfficientNet.from_pretrained('efficientnet-b0')  # Going to use efficientnet-b0 NN architecture
#EfficientNet.from_pretrained('efficientnet-b0',num_classes=targetのクラス数（今回だと2?）) 
skf = GroupKFold(n_splits=5)
model_name = "224_224_GrayColorConstancy"
train_folder = "pad_jpg/train/" + model_name
epochs = 20  # Number of epochs to run
model_path =  Output + 'model/model_' + model_name + '.pth'  # Path and filename to save model to
es_patience = 3  # Early Stopping patience - for how many epochs with no improvements to wait
bat_size = [64, 32, 16] #train, val, test
test_imfolder = [SIIM_ISIC_Melanoma_Classification + "pad_jpg/test/" + model_name]

#データ整形
train_df, test_df, tfrecord = initData2020()
dt = [train_df, test_df]
[train_df, test_df] = TableDataPreprocess2020(dt)


#実行
test_preds, metaval_preds, metaval_ID = Exec_TTAmod(epochs, model_path, es_patience, bat_size, train_df, test_df, 
                                                    test_imfolder, arch, tfrecord)

sns.kdeplot(pd.Series(test_preds.cpu().numpy().reshape(-1,)));
sns.kdeplot(pd.Series(metaval_preds.reshape(-1,)));

#test用
test_ID = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'sample_submission.csv')
test_ID['target'] = test_preds.cpu().numpy().reshape(-1,)
test_ID.to_csv(Output + 'test/sub_test_stacking_' + model_name + '.csv', index=False)

#metaval用
#metaval_ID = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'sample_sub_metaval_stacking.csv')
metaval_ID.loc[:,"target"] = 0
metaval_ID['target'] = metaval_preds.reshape(-1,)
metaval_ID.to_csv(Output + 'metaval/sub_metaval_stacking_' + model_name + '.csv', index=False)

#test用submit
api = KaggleApi()
api.authenticate()  # 認証を通す
csv_file_path = Output + 'test/sub_test_stacking_' + model_name + '.csv'
message = 'Imgprocessing Stacking' + model_name
competition_id = 'siim-isic-melanoma-classification'
api.competition_submit(csv_file_path, message, competition_id)
# Out:
# Loaded pretrained weights for efficientnet-b0
# ==================== Fold 1 ====================
# Epoch 001: | Loss: 45.277 | Train acc: 0.969 | Val acc: 0.971 | Val roc_auc: 0.837 | Training time: 0:02:18
# Epoch 002: | Loss: 37.024 | Train acc: 0.974 | Val acc: 0.971 | Val roc_auc: 0.887 | Training time: 0:02:15
# Epoch 003: | Loss: 34.738 | Train acc: 0.975 | Val acc: 0.975 | Val roc_auc: 0.914 | Training time: 0:02:14
# Epoch 004: | Loss: 32.815 | Train acc: 0.976 | Val acc: 0.975 | Val roc_auc: 0.897 | Training time: 0:02:18
# Epoch 005: | Loss: 31.771 | Train acc: 0.977 | Val acc: 0.977 | Val roc_auc: 0.923 | Training time: 0:02:17
# Epoch 006: | Loss: 31.134 | Train acc: 0.977 | Val acc: 0.974 | Val roc_auc: 0.913 | Training time: 0:02:20
# Epoch 007: | Loss: 28.848 | Train acc: 0.979 | Val acc: 0.972 | Val roc_auc: 0.899 | Training time: 0:02:17
# Epoch     7: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 008: | Loss: 23.313 | Train acc: 0.982 | Val acc: 0.977 | Val roc_auc: 0.936 | Training time: 0:02:18
# Epoch 009: | Loss: 20.490 | Train acc: 0.984 | Val acc: 0.977 | Val roc_auc: 0.929 | Training time: 0:02:16
# Epoch 010: | Loss: 18.978 | Train acc: 0.985 | Val acc: 0.977 | Val roc_auc: 0.927 | Training time: 0:02:18
# Epoch    10: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 011: | Loss: 15.813 | Train acc: 0.988 | Val acc: 0.978 | Val roc_auc: 0.937 | Training time: 0:02:16
# Epoch 012: | Loss: 14.668 | Train acc: 0.988 | Val acc: 0.978 | Val roc_auc: 0.933 | Training time: 0:02:14
# Epoch 013: | Loss: 14.345 | Train acc: 0.989 | Val acc: 0.977 | Val roc_auc: 0.932 | Training time: 0:02:16
# Epoch    13: reducing learning rate of group 0 to 8.0000e-06.
# Epoch 014: | Loss: 13.015 | Train acc: 0.989 | Val acc: 0.977 | Val roc_auc: 0.934 | Training time: 0:02:13
# Early stopping. Best Val roc_auc: 0.937
# ==================== Fold 2 ====================
# Epoch 001: | Loss: 32.506 | Train acc: 0.977 | Val acc: 0.967 | Val roc_auc: 0.824 | Training time: 0:02:17
# Epoch 002: | Loss: 27.815 | Train acc: 0.979 | Val acc: 0.976 | Val roc_auc: 0.828 | Training time: 0:02:15
# Epoch 003: | Loss: 27.453 | Train acc: 0.980 | Val acc: 0.964 | Val roc_auc: 0.805 | Training time: 0:02:15
# Epoch 004: | Loss: 33.808 | Train acc: 0.977 | Val acc: 0.969 | Val roc_auc: 0.797 | Training time: 0:02:14
# Epoch     4: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 005: | Loss: 29.342 | Train acc: 0.978 | Val acc: 0.971 | Val roc_auc: 0.823 | Training time: 0:02:17
# Early stopping. Best Val roc_auc: 0.828
# ==================== Fold 3 ====================
# Epoch 001: | Loss: 35.421 | Train acc: 0.974 | Val acc: 0.973 | Val roc_auc: 0.819 | Training time: 0:02:14
# Epoch 002: | Loss: 28.253 | Train acc: 0.979 | Val acc: 0.973 | Val roc_auc: 0.829 | Training time: 0:02:15
# Epoch 003: | Loss: 25.634 | Train acc: 0.980 | Val acc: 0.974 | Val roc_auc: 0.833 | Training time: 0:02:16
# Epoch 004: | Loss: 24.189 | Train acc: 0.981 | Val acc: 0.969 | Val roc_auc: 0.821 | Training time: 0:02:13
# Epoch 005: | Loss: 23.058 | Train acc: 0.983 | Val acc: 0.972 | Val roc_auc: 0.824 | Training time: 0:02:13
# Epoch     5: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 006: | Loss: 16.646 | Train acc: 0.987 | Val acc: 0.972 | Val roc_auc: 0.840 | Training time: 0:02:13
# Epoch 007: | Loss: 13.925 | Train acc: 0.989 | Val acc: 0.972 | Val roc_auc: 0.836 | Training time: 0:02:13
# Epoch 008: | Loss: 11.831 | Train acc: 0.991 | Val acc: 0.974 | Val roc_auc: 0.830 | Training time: 0:02:13
# Epoch     8: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 009: | Loss: 9.994 | Train acc: 0.992 | Val acc: 0.973 | Val roc_auc: 0.834 | Training time: 0:02:13
# Early stopping. Best Val roc_auc: 0.840
# ==================== Fold 4 ====================
# Epoch 001: | Loss: 24.498 | Train acc: 0.981 | Val acc: 0.976 | Val roc_auc: 0.849 | Training time: 0:02:13
# Epoch 002: | Loss: 20.509 | Train acc: 0.984 | Val acc: 0.975 | Val roc_auc: 0.840 | Training time: 0:02:13
# Epoch 003: | Loss: 18.881 | Train acc: 0.985 | Val acc: 0.975 | Val roc_auc: 0.851 | Training time: 0:02:13
# Epoch 004: | Loss: 18.759 | Train acc: 0.985 | Val acc: 0.973 | Val roc_auc: 0.837 | Training time: 0:02:13
# Epoch 005: | Loss: 16.692 | Train acc: 0.987 | Val acc: 0.974 | Val roc_auc: 0.846 | Training time: 0:02:13
# Epoch     5: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 006: | Loss: 11.091 | Train acc: 0.991 | Val acc: 0.977 | Val roc_auc: 0.849 | Training time: 0:02:13
# Early stopping. Best Val roc_auc: 0.851
# ==================== Fold 5 ====================
# Epoch 001: | Loss: 19.867 | Train acc: 0.985 | Val acc: 0.982 | Val roc_auc: 0.872 | Training time: 0:02:13
# Epoch 002: | Loss: 15.857 | Train acc: 0.988 | Val acc: 0.980 | Val roc_auc: 0.870 | Training time: 0:02:14
# Epoch 003: | Loss: 14.494 | Train acc: 0.989 | Val acc: 0.976 | Val roc_auc: 0.864 | Training time: 0:02:13
# Epoch     3: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 004: | Loss: 9.030 | Train acc: 0.993 | Val acc: 0.983 | Val roc_auc: 0.870 | Training time: 0:02:13
# Early stopping. Best Val roc_auc: 0.872
# OOF: 0.856
# 100%|██████████| 274k/274k [00:04<00:00, 68.6kB/s]
# CPU times: user 57min 56s, sys: 25min 15s, total: 1h 23min 12s
# Wall time: 1h 28min 11s
# Successfully submitted to SIIM-ISIC Melanoma Classification

# %%
# %%time
#224_224_GrayColorConstancy 
arch = EfficientNet.from_pretrained('efficientnet-b0')  # Going to use efficientnet-b0 NN architecture
#EfficientNet.from_pretrained('efficientnet-b0',num_classes=targetのクラス数（今回だと2?）) 
skf = GroupKFold(n_splits=5)
model_name = "224_224_GrayColorConstancy"
train_folder = "pad_jpg/train/" + model_name
epochs = 20  # Number of epochs to run
model_path =  Output + 'model/model_' + model_name + '.pth'  # Path and filename to save model to
es_patience = 3  # Early Stopping patience - for how many epochs with no improvements to wait
bat_size = [64, 32, 16] #train, val, test
test_imfolder = [SIIM_ISIC_Melanoma_Classification + "pad_jpg/test/" + model_name]

#データ整形
train_df, test_df, tfrecord = initData2020()
dt = [train_df, test_df]
[train_df, test_df] = TableDataPreprocess2020(dt)


#実行
test_preds, metaval_preds, metaval_ID = Exec_TTAmod(epochs, model_path, es_patience, bat_size, train_df, test_df, 
                                                    test_imfolder, arch, tfrecord)

sns.kdeplot(pd.Series(test_preds.cpu().numpy().reshape(-1,)));
sns.kdeplot(pd.Series(metaval_preds.reshape(-1,)));

#test用
test_ID = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'sample_submission.csv')
test_ID['target'] = test_preds.cpu().numpy().reshape(-1,)
test_ID.to_csv(Output + 'test/sub_test_stacking_' + model_name + '.csv', index=False)

#metaval用
#metaval_ID = pd.read_csv(SIIM_ISIC_Melanoma_Classification + 'sample_sub_metaval_stacking.csv')
metaval_ID.loc[:,"target"] = 0
metaval_ID['target'] = metaval_preds.reshape(-1,)
metaval_ID.to_csv(Output + 'metaval/sub_metaval_stacking_' + model_name + '.csv', index=False)

#test用submit
api = KaggleApi()
api.authenticate()  # 認証を通す
csv_file_path = Output + 'test/sub_test_stacking_' + model_name + '.csv'
message = 'Imgprocessing Stacking' + model_name
competition_id = 'siim-isic-melanoma-classification'
api.competition_submit(csv_file_path, message, competition_id)
# Out:
# Loaded pretrained weights for efficientnet-b0
# ==================== Fold 1 ====================
# Epoch 001: | Loss: 45.927 | Train acc: 0.967 | Val acc: 0.974 | Val roc_auc: 0.898 | Training time: 0:02:12
# Epoch 002: | Loss: 39.155 | Train acc: 0.973 | Val acc: 0.974 | Val roc_auc: 0.888 | Training time: 0:02:12
# Epoch 003: | Loss: 37.020 | Train acc: 0.974 | Val acc: 0.971 | Val roc_auc: 0.895 | Training time: 0:02:12
# Epoch     3: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 004: | Loss: 30.959 | Train acc: 0.978 | Val acc: 0.979 | Val roc_auc: 0.924 | Training time: 0:02:12
# Epoch 005: | Loss: 26.967 | Train acc: 0.980 | Val acc: 0.977 | Val roc_auc: 0.931 | Training time: 0:02:12
# Epoch 006: | Loss: 25.814 | Train acc: 0.980 | Val acc: 0.978 | Val roc_auc: 0.924 | Training time: 0:02:12
# Epoch 007: | Loss: 23.922 | Train acc: 0.981 | Val acc: 0.978 | Val roc_auc: 0.921 | Training time: 0:02:12
# Epoch     7: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 008: | Loss: 21.001 | Train acc: 0.984 | Val acc: 0.979 | Val roc_auc: 0.928 | Training time: 0:02:12
# Early stopping. Best Val roc_auc: 0.931
# ==================== Fold 2 ====================
# Epoch 001: | Loss: 38.989 | Train acc: 0.972 | Val acc: 0.968 | Val roc_auc: 0.812 | Training time: 0:02:12
# Epoch 002: | Loss: 32.420 | Train acc: 0.977 | Val acc: 0.968 | Val roc_auc: 0.747 | Training time: 0:02:12
# Epoch 003: | Loss: 31.759 | Train acc: 0.978 | Val acc: 0.967 | Val roc_auc: 0.814 | Training time: 0:02:12
# Epoch 004: | Loss: 30.529 | Train acc: 0.978 | Val acc: 0.945 | Val roc_auc: 0.786 | Training time: 0:02:12
# Epoch 005: | Loss: 30.189 | Train acc: 0.979 | Val acc: 0.964 | Val roc_auc: 0.806 | Training time: 0:02:12
# Epoch     5: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 006: | Loss: 22.491 | Train acc: 0.983 | Val acc: 0.972 | Val roc_auc: 0.825 | Training time: 0:02:12
# Epoch 007: | Loss: 20.285 | Train acc: 0.984 | Val acc: 0.973 | Val roc_auc: 0.823 | Training time: 0:02:12
# Epoch 008: | Loss: 18.242 | Train acc: 0.985 | Val acc: 0.974 | Val roc_auc: 0.823 | Training time: 0:02:12
# Epoch     8: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 009: | Loss: 15.465 | Train acc: 0.987 | Val acc: 0.973 | Val roc_auc: 0.825 | Training time: 0:02:12
# Early stopping. Best Val roc_auc: 0.825
# ==================== Fold 3 ====================
# Epoch 001: | Loss: 29.624 | Train acc: 0.978 | Val acc: 0.974 | Val roc_auc: 0.840 | Training time: 0:02:12
# Epoch 002: | Loss: 27.818 | Train acc: 0.980 | Val acc: 0.973 | Val roc_auc: 0.826 | Training time: 0:02:12
# Epoch 003: | Loss: 24.538 | Train acc: 0.981 | Val acc: 0.972 | Val roc_auc: 0.839 | Training time: 0:02:12
# Epoch     3: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 004: | Loss: 18.404 | Train acc: 0.985 | Val acc: 0.976 | Val roc_auc: 0.844 | Training time: 0:02:13
# Epoch 005: | Loss: 14.903 | Train acc: 0.988 | Val acc: 0.976 | Val roc_auc: 0.851 | Training time: 0:02:12
# Epoch 006: | Loss: 13.205 | Train acc: 0.989 | Val acc: 0.974 | Val roc_auc: 0.846 | Training time: 0:02:12
# Epoch 007: | Loss: 10.999 | Train acc: 0.992 | Val acc: 0.976 | Val roc_auc: 0.847 | Training time: 0:02:12
# Epoch     7: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 008: | Loss: 9.075 | Train acc: 0.993 | Val acc: 0.974 | Val roc_auc: 0.847 | Training time: 0:02:12
# Early stopping. Best Val roc_auc: 0.851
# ==================== Fold 4 ====================
# Epoch 001: | Loss: 24.739 | Train acc: 0.980 | Val acc: 0.968 | Val roc_auc: 0.848 | Training time: 0:02:12
# Epoch 002: | Loss: 23.516 | Train acc: 0.981 | Val acc: 0.970 | Val roc_auc: 0.832 | Training time: 0:02:12
# Epoch 003: | Loss: 21.906 | Train acc: 0.983 | Val acc: 0.974 | Val roc_auc: 0.845 | Training time: 0:02:12
# Epoch     3: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 004: | Loss: 14.965 | Train acc: 0.988 | Val acc: 0.974 | Val roc_auc: 0.854 | Training time: 0:02:12
# Epoch 005: | Loss: 11.241 | Train acc: 0.991 | Val acc: 0.976 | Val roc_auc: 0.854 | Training time: 0:02:12
# Epoch 006: | Loss: 10.161 | Train acc: 0.992 | Val acc: 0.978 | Val roc_auc: 0.853 | Training time: 0:02:13
# Epoch 007: | Loss: 8.875 | Train acc: 0.993 | Val acc: 0.979 | Val roc_auc: 0.856 | Training time: 0:02:12
# Epoch 008: | Loss: 7.906 | Train acc: 0.994 | Val acc: 0.977 | Val roc_auc: 0.858 | Training time: 0:02:12
# Epoch 009: | Loss: 7.824 | Train acc: 0.994 | Val acc: 0.977 | Val roc_auc: 0.855 | Training time: 0:02:12
# Epoch 010: | Loss: 6.791 | Train acc: 0.995 | Val acc: 0.977 | Val roc_auc: 0.857 | Training time: 0:02:12
# Epoch    10: reducing learning rate of group 0 to 4.0000e-05.
# Epoch 011: | Loss: 5.189 | Train acc: 0.996 | Val acc: 0.979 | Val roc_auc: 0.854 | Training time: 0:02:12
# Early stopping. Best Val roc_auc: 0.858
# ==================== Fold 5 ====================
# Epoch 001: | Loss: 20.320 | Train acc: 0.983 | Val acc: 0.968 | Val roc_auc: 0.868 | Training time: 0:02:12
# Epoch 002: | Loss: 16.959 | Train acc: 0.987 | Val acc: 0.975 | Val roc_auc: 0.855 | Training time: 0:02:12
# Epoch 003: | Loss: 21.651 | Train acc: 0.983 | Val acc: 0.969 | Val roc_auc: 0.813 | Training time: 0:02:12
# Epoch     3: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 004: | Loss: 17.766 | Train acc: 0.986 | Val acc: 0.976 | Val roc_auc: 0.861 | Training time: 0:02:13
# Early stopping. Best Val roc_auc: 0.868
# OOF: 0.861
# 100%|██████████| 273k/273k [00:03<00:00, 87.6kB/s]
# CPU times: user 59min 47s, sys: 26min 16s, total: 1h 26min 3s
# Wall time: 1h 31min 9s
# Successfully submitted to SIIM-ISIC Melanoma Classification
